# %%
import numpy as np
# ^^^ pyforest auto-imports - don't write above this line
import scipy.io
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rcParams
import statistics

# %%
mat = scipy.io.loadmat('./Data/ACC/P01.mat')
print(mat)
print(type(mat['tremorxf']))
print(np.array(mat['tremorxf']).shape)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Fri Jul 16 10:52:36 2021', '__version__': '1.0', '__globals__': [], 'tremorxf': array([[-0.0564624 , -0.0834893 , -0.11088602, ...,  0.04539591,
#          0.03694786,  0.0295336 ]]), 'tremoryf': array([[-0.02469609, -0.05011672, -0.07582482, ..., -0.01321981,
#         -0.01065775, -0.00843823]]), 'tremorzf': array([[ 0.39712274,  0.3886055 ,  0.37957652, ..., -0.02129843,
#         -0.01741734, -0.01398787]])}
# <class 'numpy.ndarray'>
# (1, 375518)

# %%
# 0 to (length of data)/sampling freq
from matplotlib import rcParams
rcParams['figure.figsize'] = 50,10
plt.plot(mat['tremorxf'][0,:],'r.')
plt.plot(mat['tremoryf'][0,:])
plt.grid(True,color = "k",linestyle=":")
plt.xlabel("Time")
plt.ylabel("Accelerometer values")
plt.style.use('ggplot')
#plt.legend()

# %%
rcParams['figure.figsize'] = 50,10
plt.plot(mat['tremorzf'][0,:],'r.')
#plt.plot(mat['tremoryf'][0,:])
plt.grid(True,color = "k",linestyle=":")
plt.xlabel("Time")
plt.ylabel("Accelerometer values")
plt.style.use('ggplot')

# %%
import pandas as pd
def z_score(df):
    # copy the dataframe
    df_std = df.copy()
    # apply the z-score method
    for column in df_std.columns:
        df_std[column] = (df_std[column] - df_std[column].mean()) / df_std[column].std()
        
    return df_std
    
"""df_cars = pd.DataFrame(mat['tremorxf'][0,:])
print(df_cars.shape)
# call the z_score function
df_cars_standardized = z_score(df_cars)"""
# Out:
# (375518, 1)

# %%
"""i = list()
k = list()
count =0
for j in df_cars_standardized[0]:
    k.append(j)
    count+=1
    if count == 999:
        i.append(k)
        count=0
        k = list()"""

# %%
"""rcParams['figure.figsize'] = 10,5
plt.plot(i)"""

# %%
"""#patient
mat = scipy.io.loadmat('./Data/ACC/P01.mat')
#Line plot
rcParams['figure.figsize'] = 10,5
plt.plot(mat['tremorxf'][0,:])
plt.plot(mat['tremoryf'][0,:])
plt.plot(mat['tremorzf'][0,:])
plt.grid(True,color = "k",linestyle=":")
plt.xlabel("Time")
plt.ylabel("Accelerometer values")
plt.style.use('ggplot')"""

# %%
#For x-axis
df_cars = pd.DataFrame(mat['tremorxf'][0,:])
# call the z_score function
df_cars_standardized = z_score(df_cars)
#Ploting
ix = list()
k = list()
mx = list()
count =0
for j in df_cars_standardized[0]:
    k.append(j)
    count+=1
    if count == 999:
        mx.append(statistics.mean(k))
        ix.append(k)
        count=0
        k = list()
rcParams['figure.figsize'] = 15,5
plt.xlabel("Time")
plt.ylabel("Accelerometer values")
plt.plot(ix)

# %%
rcParams['figure.figsize'] = 15,5
plt.xlabel("Time")
plt.ylabel("Mean of accelerometer values")
plt.plot(mx)

# %%
#For y-axis
df_cars = pd.DataFrame(mat['tremoryf'][0,:])
# call the z_score function
df_cars_standardized = z_score(df_cars)
#Ploting
iy = list()
k = list()
my = list()
count =0
for j in df_cars_standardized[0]:
    k.append(j)
    count+=1
    if count == 999:
        my.append(statistics.mean(k))
        iy.append(k)
        count=0
        k = list()
rcParams['figure.figsize'] = 15,5
plt.xlabel("Time")
plt.ylabel("Accelerometer values")
plt.plot(iy)

# %%
rcParams['figure.figsize'] = 15,5
plt.xlabel("Time")
plt.ylabel("Mean of accelerometer values")
plt.plot(my)

# %%
#For z-axis
df_cars = pd.DataFrame(mat['tremorzf'][0,:])
# call the z_score function
df_cars_standardized = z_score(df_cars)
#Ploting
iz = list()
k = list()
mz = list()
count =0
for j in df_cars_standardized[0]:
    k.append(j)
    count+=1
    if count == 999:
        mz.append(statistics.mean(k))
        iz.append(k)
        count=0
        k = list()
rcParams['figure.figsize'] = 15,5
plt.xlabel("Time")
plt.ylabel("Accelerometer values")
plt.plot(iz)

# %%
rcParams['figure.figsize'] = 15,5
plt.xlabel("Time")
plt.ylabel("Mean of accelerometer values")
plt.plot(mz)

# %%
plt.xlabel("Time")
plt.ylabel("Means of three x-axis, y-axis and z-axis")
plt.plot(mx)
#plt.plot(my)
plt.plot(mz)

# %%
plt.plot(ix)
plt.plot(iy)
plt.plot(iz)

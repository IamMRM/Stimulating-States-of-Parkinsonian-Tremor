# %%
import numpy as np

# %%
acc_withoutEnv = np.load("acc_withoutEnvelope.npy")
print(acc_withoutEnv.shape)
print(len(acc_withoutEnv[0][0][0]))
# Out:
# (10, 3, 7)
# 75

# %%
acc_withEnv = np.load("acc_withEnvelope.npy")
print(acc_withEnv.shape)
a= np.moveaxis(acc_withEnv, -1, 0)
b=np.array(a[0][0][0])
print(len(a[0][0][0]))
print(len(acc_withEnv[0][0][0]))
# Out:
# (10, 3, 7)
# 75
# 75

# %%
emg_withoutEnv = np.load("emg_withoutEnvelope.npy")
print(emg_withoutEnv.shape)
print(len(emg_withoutEnv[0][0][0]))
# Out:
# (10, 3, 7)
# 75

# %%
75+61+60+28+115+62+64+63+80+74
# Out:
# 682

# %%
7*3*4
# Out:
# 84

# %%
emg_withEnv = np.load("emg_withEnvelope.npy")
print(emg_withEnv.shape)
print(len(emg_withEnv[0][0][0]))
acc_withoutEnv[0][0][0][0]
# Out:
# (10, 3, 7)
# 75
# 8.857697921213935e-05

# %%
count=0
feche=np.zeros(shape=(682,84))
print(feche[0].shape)
vari=np.zeros((84))
print(vari.shape)

for i in range(len(acc_withoutEnv)):#patient
    for j in range(len(acc_withoutEnv[i][0][0])):#75
        cc=0
        vari[cc]=acc_withoutEnv[i][0][0][j]
        vari[cc+1]=acc_withoutEnv[i][1][0][j]
        vari[cc+2]=acc_withoutEnv[i][2][0][j]
        
        vari[cc+3]=acc_withoutEnv[i][0][1][j]
        vari[cc+4]=acc_withoutEnv[i][1][1][j]
        vari[cc+5]=acc_withoutEnv[i][2][1][j]
        
        vari[cc+6]=acc_withoutEnv[i][0][2][j]
        vari[cc+7]=acc_withoutEnv[i][1][2][j]
        vari[cc+8]=acc_withoutEnv[i][2][2][j]
        
        vari[cc+9]=acc_withoutEnv[i][0][3][j]
        vari[cc+10]=acc_withoutEnv[i][1][3][j]
        vari[cc+11]=acc_withoutEnv[i][2][3][j]
        
        vari[cc+12]=acc_withoutEnv[i][0][4][j]
        vari[cc+13]=acc_withoutEnv[i][1][4][j]
        vari[cc+14]=acc_withoutEnv[i][2][4][j]
        
        vari[cc+15]=acc_withoutEnv[i][0][5][j]
        vari[cc+16]=acc_withoutEnv[i][1][5][j]
        vari[cc+17]=acc_withoutEnv[i][2][5][j]
                
        vari[cc+18]=acc_withoutEnv[i][0][6][j]
        vari[cc+19]=acc_withoutEnv[i][1][6][j]
        vari[cc+20]=acc_withoutEnv[i][2][6][j]
        cc=21
        vari[cc]=acc_withEnv[i][0][0][j]
        vari[cc+1]=acc_withEnv[i][1][0][j]
        vari[cc+2]=acc_withEnv[i][2][0][j]

        vari[cc+3]=acc_withEnv[i][0][1][j]
        vari[cc+4]=acc_withEnv[i][1][1][j]
        vari[cc+5]=acc_withEnv[i][2][1][j]

        vari[cc+6]=acc_withEnv[i][0][2][j]
        vari[cc+7]=acc_withEnv[i][1][2][j]
        vari[cc+8]=acc_withEnv[i][2][2][j]

        vari[cc+9]=acc_withEnv[i][0][3][j]
        vari[cc+10]=acc_withEnv[i][1][3][j]
        vari[cc+11]=acc_withEnv[i][2][3][j]

        vari[cc+12]=acc_withEnv[i][0][4][j]
        vari[cc+13]=acc_withEnv[i][1][4][j]
        vari[cc+14]=acc_withEnv[i][2][4][j]

        vari[cc+15]=acc_withEnv[i][0][5][j]
        vari[cc+16]=acc_withEnv[i][1][5][j]
        vari[cc+17]=acc_withEnv[i][2][5][j]

        vari[cc+18]=acc_withEnv[i][0][6][j]
        vari[cc+19]=acc_withEnv[i][1][6][j]
        vari[cc+20]=acc_withEnv[i][2][6][j]  
        cc=42
        vari[cc]=emg_withoutEnv[i][0][0][j]
        vari[cc+1]=emg_withoutEnv[i][1][0][j]
        vari[cc+2]=emg_withoutEnv[i][2][0][j]

        vari[cc+3]=emg_withoutEnv[i][0][1][j]
        vari[cc+4]=emg_withoutEnv[i][1][1][j]
        vari[cc+5]=emg_withoutEnv[i][2][1][j]

        vari[cc+6]=emg_withoutEnv[i][0][2][j]
        vari[cc+7]=emg_withoutEnv[i][1][2][j]
        vari[cc+8]=emg_withoutEnv[i][2][2][j]

        vari[cc+9]=emg_withoutEnv[i][0][3][j]
        vari[cc+10]=emg_withoutEnv[i][1][3][j]
        vari[cc+11]=emg_withoutEnv[i][2][3][j]

        vari[cc+12]=emg_withoutEnv[i][0][4][j]
        vari[cc+13]=emg_withoutEnv[i][1][4][j]
        vari[cc+14]=emg_withoutEnv[i][2][4][j]

        vari[cc+15]=emg_withoutEnv[i][0][5][j]
        vari[cc+16]=emg_withoutEnv[i][1][5][j]
        vari[cc+17]=emg_withoutEnv[i][2][5][j]

        vari[cc+18]=emg_withoutEnv[i][0][6][j]
        vari[cc+19]=emg_withoutEnv[i][1][6][j]
        vari[cc+20]=emg_withoutEnv[i][2][6][j]
        cc=63
        vari[cc]=emg_withEnv[i][0][0][j]
        vari[cc+1]=emg_withEnv[i][1][0][j]
        vari[cc+2]=emg_withEnv[i][2][0][j]

        vari[cc+3]=emg_withEnv[i][0][1][j]
        vari[cc+4]=emg_withEnv[i][1][1][j]
        vari[cc+5]=emg_withEnv[i][2][1][j]

        vari[cc+6]=emg_withEnv[i][0][2][j]
        vari[cc+7]=emg_withEnv[i][1][2][j]
        vari[cc+8]=emg_withEnv[i][2][2][j]

        vari[cc+9]=emg_withEnv[i][0][3][j]
        vari[cc+10]=emg_withEnv[i][1][3][j]
        vari[cc+11]=emg_withEnv[i][2][3][j]

        vari[cc+12]=emg_withEnv[i][0][4][j]
        vari[cc+13]=emg_withEnv[i][1][4][j]
        vari[cc+14]=emg_withEnv[i][2][4][j]

        vari[cc+15]=emg_withEnv[i][0][5][j]
        vari[cc+16]=emg_withEnv[i][1][5][j]
        vari[cc+17]=emg_withEnv[i][2][5][j]

        vari[cc+18]=emg_withEnv[i][0][6][j]
        vari[cc+19]=emg_withEnv[i][1][6][j]
        vari[cc+20]=emg_withEnv[i][2][6][j]
        
        
        feche[count]=vari
        count+=1
print(count)
# Out:
# (84,)
# (84,)
# 682

# %%
print(feche.shape)
# Out:
# (682, 84)

# %%
feature_space=[]
temp=[]
for i in range(len(acc_withoutEnv)):#patient
    for j in range(len(acc_withoutEnv[i])):#axis
        for k in range(len(acc_withoutEnv[i][j])):#features
            for l in range(len(acc_withoutEnv[i][j][k])):#each value
                temp.append(acc_withoutEnv[i][j][k][l])
                temp.append(acc_withEnv[i][j][k][l])
                temp.append(emg_withoutEnv[i][j][k][l])
                temp.append(emg_withEnv[i][j][k][l])
    feature_space.append(temp)
    temp=[]

# %%
print(len(feature_space))
print(len(feature_space[0]))
print(np.array(feature_space).shape)
# Out:
# 10
# 6300
# (10,)

# %%
import matplotlib.pyplot as plt
plt.plot(feche,'r.')
plt.xlabel("5 second instances")
plt.ylabel("Value of features")
plt.show()

# %%
plt.plot(feche)
plt.xlabel("5 second instances")
plt.ylabel("Value of features")
plt.show()

# %%
from sklearn.cluster import DBSCAN
clustering = DBSCAN(eps=50,min_samples=2).fit(feche)
cluster=clustering.labels_

# %%
print(len(set(cluster)))
unique, counts = np.unique(cluster, return_counts=True)
dict(zip(unique, counts))
# Out:
# 6
# {-1: 77, 0: 590, 1: 5, 2: 2, 3: 5, 4: 3}

# %%
plt.scatter(feche[:,0],cluster)
plt.show()

# %%
plt.scatter(feche[:,1],cluster)
plt.show()

# %%
plt.scatter(feche[:,5],cluster)
plt.show()

# %%
plt.scatter(feche[:,10],cluster)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rcParams
# ^^^ pyforest auto-imports - don't write above this line
import numpy as np
import scipy.io
from scipy.fftpack import fft
from scipy import signal
from scipy.signal import hilbert

# %%
data = np.load("acc.npy")
print(data.shape)
print(len(data[0][0]))
print(len(data[0][0][0]))
# Out:
# (10, 3)
# 75
# 5000

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import hilbert
analytic_signal = hilbert(data[3][0][0])
amplitude_envelope = np.abs(analytic_signal)

plt.plot(data[3][0][0], label='signal')
plt.plot(amplitude_envelope, label='envelope')
plt.show()

# %%
te=[]
tem=[]
envelope = []
for pat in data:#per patient
    for axis in pat:#per axis
        for inst in axis:
            """analytic_signal = hilbert(inst)
            amplitude_envelope = np.abs(analytic_signal)
            te.append(amplitude_envelope)"""
            te.append(max(inst))
        tem.append(te)
        te=[]
    envelope.append(tem)
    tem=[]
print(len(envelope))
print(len(envelope[0]))
print(len(envelope[0][0]))
print((envelope[0][0][0]))
# Out:
# 10
# 3
# 75
# 0.42279562312678753

# %%
count=0
for i in envelope[0][0]:
    if i > 1.0:
        count+=1
count
# Out:
# 52

# %%
# 0 to (length of data)/sampling freq
from matplotlib import rcParams
rcParams['figure.figsize'] = 50,10
plt.plot(envelope[0][2])
plt.grid(True,color = "k",linestyle=":")
plt.xlabel("Time")
plt.ylabel("ACC values")
plt.style.use('ggplot')
plt.ylim(-3,+4)
#plt.legend()
# Out:
# (-3, 4)

# %%
# 0 to (length of data)/sampling freq
from matplotlib import rcParams
rcParams['figure.figsize'] = 50,10
plt.plot(data[0][0])
plt.grid(True,color = "k",linestyle=":")
plt.xlabel("Time")
plt.ylabel("ACC values")
plt.style.use('ggplot')
plt.ylim(-3,+4)
#plt.legend()
# Out:
# (-3, 4)

# %%
# 0 to (length of data)/sampling freq
from matplotlib import rcParams
rcParams['figure.figsize'] = 50,10
plt.plot(envelope[0][1])
plt.grid(True,color = "k",linestyle=":")
plt.xlabel("Time")
plt.ylabel("ACC values")
plt.style.use('ggplot')
plt.ylim(-3,+3)
#plt.legend()
# Out:
# (-3, 3)

# %%
# 0 to (length of data)/sampling freq
from matplotlib import rcParams
rcParams['figure.figsize'] = 50,10
plt.plot(envelope[0][2])
plt.grid(True,color = "k",linestyle=":")
plt.xlabel("Time")
plt.ylabel("ACC values")
plt.style.use('ggplot')
plt.ylim(-3,+3)
#plt.legend()
# Out:
# (-3, 3)

# %%
# 0 to (length of data)/sampling freq
from matplotlib import rcParams
rcParams['figure.figsize'] = 50,10
plt.plot(envelope[1][0])
plt.grid(True,color = "k",linestyle=":")
plt.xlabel("Time")
plt.ylabel("ACC values")
plt.style.use('ggplot')
plt.ylim(-3,+3)
#plt.legend()
# Out:
# (-3, 3)

# %%
# 0 to (length of data)/sampling freq
from matplotlib import rcParams
rcParams['figure.figsize'] = 50,10
plt.plot(envelope[1][1])
plt.grid(True,color = "k",linestyle=":")
plt.xlabel("Time")
plt.ylabel("ACC values")
plt.style.use('ggplot')
plt.ylim(-3,+3)
#plt.legend()
# Out:
# (-3, 3)

# %%
# 0 to (length of data)/sampling freq
from matplotlib import rcParams
rcParams['figure.figsize'] = 50,10
plt.plot(envelope[1][2])
plt.grid(True,color = "k",linestyle=":")
plt.xlabel("Time")
plt.ylabel("ACC values")
plt.style.use('ggplot')
plt.ylim(-3,+3)
#plt.legend()
# Out:
# (-3, 3)
